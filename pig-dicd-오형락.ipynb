# %%
from random import randint
from time import sleep


scoreboard = [0, 0]
goal_score = 100
is_game_over = False

while True:
    is_turn_on = True
    player_turn_score = 0
    rolled = 0
    while is_turn_on!='h':
        print("==============")
        print("Player's turn!")
        rolled = randint(1,6)
        if rolled==1:
            player_turn_score=0
            print("Oh, you got 1! Ending your turn..")
            break
        else:
            player_turn_score+=rolled
            print(f"You got {rolled}, and You have {player_turn_score}.")
            if scoreboard[0]+player_turn_score>=goal_score:
                is_game_over=True
                break
            is_turn_on = input("Roll(r) or Hold(h)> ").lower()

    if is_game_over==True:
        print(f"Congrats! Player have achieved {goal_score}.")
        break
    scoreboard[0]+=player_turn_score
    print(f'Scoreboard: {scoreboard}')

    com_turn_score = 0
    rolled=0
    while com_turn_score<=30:
        print("================")
        print("Com's Show time!")
        sleep(1)
        rolled = randint(1,6)
        if rolled==1:
            com_turn_score=0
            print("Uh-oh.. Com got 1.. I got nothin' on this turn..")
            break
        else:
            com_turn_score+=rolled
            print(f"I got {rolled}, and I have {com_turn_score}.")
            if scoreboard[1]+com_turn_score>=goal_score:
                is_game_over=True
                break
    if is_game_over==True:
        print(f"Game Over! Computer have achieved {goal_score}")
        break
    scoreboard[1]+=com_turn_score
    print(f'Scoreboard: {scoreboard}')
# Out:
# ==============
# Player's turn!
# You got 4, and You have 4.
# Roll(r) or Hold(h)> ㄱ
# ==============
# Player's turn!
# You got 6, and You have 10.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# Oh, you got 1! Ending your turn..
# Scoreboard: [0, 0]
# ================
# Com's Show time!
# I got 5, and I have 5.
# ================
# Com's Show time!
# I got 4, and I have 9.
# ================
# Com's Show time!
# I got 2, and I have 11.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [0, 0]
# ==============
# Player's turn!
# You got 2, and You have 2.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 3, and You have 5.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 5, and You have 10.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# Oh, you got 1! Ending your turn..
# Scoreboard: [0, 0]
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [0, 0]
# ==============
# Player's turn!
# You got 4, and You have 4.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 2, and You have 6.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# Oh, you got 1! Ending your turn..
# Scoreboard: [0, 0]
# ================
# Com's Show time!
# I got 4, and I have 4.
# ================
# Com's Show time!
# I got 6, and I have 10.
# ================
# Com's Show time!
# I got 6, and I have 16.
# ================
# Com's Show time!
# I got 6, and I have 22.
# ================
# Com's Show time!
# I got 2, and I have 24.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [0, 0]
# ==============
# Player's turn!
# You got 2, and You have 2.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 5, and You have 7.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 2, and You have 9.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 5, and You have 14.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 4, and You have 18.
# Roll(r) or Hold(h)> h
# Scoreboard: [18, 0]
# ================
# Com's Show time!
# I got 6, and I have 6.
# ================
# Com's Show time!
# I got 3, and I have 9.
# ================
# Com's Show time!
# I got 4, and I have 13.
# ================
# Com's Show time!
# I got 2, and I have 15.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [18, 0]
# ==============
# Player's turn!
# You got 6, and You have 6.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 6, and You have 12.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 6, and You have 18.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 3, and You have 21.
# Roll(r) or Hold(h)> h
# Scoreboard: [39, 0]
# ================
# Com's Show time!
# I got 6, and I have 6.
# ================
# Com's Show time!
# I got 6, and I have 12.
# ================
# Com's Show time!
# I got 3, and I have 15.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [39, 0]
# ==============
# Player's turn!
# You got 2, and You have 2.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# Oh, you got 1! Ending your turn..
# Scoreboard: [39, 0]
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [39, 0]
# ==============
# Player's turn!
# You got 4, and You have 4.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 6, and You have 10.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 5, and You have 15.
# Roll(r) or Hold(h)> h
# Scoreboard: [54, 0]
# ================
# Com's Show time!
# I got 6, and I have 6.
# ================
# Com's Show time!
# I got 5, and I have 11.
# ================
# Com's Show time!
# I got 2, and I have 13.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [54, 0]
# ==============
# Player's turn!
# You got 3, and You have 3.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 6, and You have 9.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 5, and You have 14.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 4, and You have 18.
# Roll(r) or Hold(h)> h
# Scoreboard: [72, 0]
# ================
# Com's Show time!
# I got 6, and I have 6.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [72, 0]
# ==============
# Player's turn!
# You got 6, and You have 6.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 5, and You have 11.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# Oh, you got 1! Ending your turn..
# Scoreboard: [72, 0]
# ================
# Com's Show time!
# I got 4, and I have 4.
# ================
# Com's Show time!
# I got 2, and I have 6.
# ================
# Com's Show time!
# I got 6, and I have 12.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [72, 0]
# ==============
# Player's turn!
# You got 6, and You have 6.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 6, and You have 12.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 4, and You have 16.
# Roll(r) or Hold(h)> h
# Scoreboard: [88, 0]
# ================
# Com's Show time!
# I got 6, and I have 6.
# ================
# Com's Show time!
# I got 2, and I have 8.
# ================
# Com's Show time!
# I got 4, and I have 12.
# ================
# Com's Show time!
# I got 4, and I have 16.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [88, 0]
# ==============
# Player's turn!
# You got 2, and You have 2.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 5, and You have 7.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# Oh, you got 1! Ending your turn..
# Scoreboard: [88, 0]
# ================
# Com's Show time!
# I got 2, and I have 2.
# ================
# Com's Show time!
# Uh-oh.. Com got 1.. I got nothin' on this turn..
# Scoreboard: [88, 0]
# ==============
# Player's turn!
# You got 6, and You have 6.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 2, and You have 8.
# Roll(r) or Hold(h)> r
# ==============
# Player's turn!
# You got 4, and You have 12.
# Congrats! Player have achieved 100.
